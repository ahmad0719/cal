# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmad0719/cal/blob/main/AhmadAssadJanjua.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

# 1. Generate sample synthetic dataset with 4 clusters
X, _ = make_blobs(n_samples=300, centers=4, cluster_std=0.60, random_state=42)

# 2. Fit K-Means clustering model
kmeans = KMeans(n_clusters=4, random_state=42, n_init=10)
y_kmeans = kmeans.fit_predict(X)
centroids = kmeans.cluster_centers_

# 3. Create the scatter plot
plt.figure(figsize=(8, 6))

# Plot data points colored by cluster assignment
scatter = plt.scatter(
    X[:, 0],
    X[:, 1],
    c=y_kmeans,
    cmap='viridis',
    s=50,
    alpha=0.8,
    edgecolors='k',
    label='Data Points',
)

# Plot cluster centroids
plt.scatter(
    centroids[:, 0],
    centroids[:, 1],
    c='red',
    marker='X',
    s=200,
    linewidths=2,
    label='Centroids',
)

# Formatting
plt.title('Clustered Groups Visualization', fontsize=14)
plt.xlabel('Feature 1', fontsize=12)
plt.ylabel('Feature 2', fontsize=12)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()
